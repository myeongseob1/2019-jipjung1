# %% [markdown]
# <p><img alt="Colaboratory logo" height="45px" src="https://colab.research.google.com/img/colab_favicon.ico" align="left" hspace="10px" vspace="0px"></p>
#
# <h1>Welcome to Colaboratory!</h1>
#
#
# Colaboratory is a free Jupyter notebook environment that requires no setup and runs entirely in the cloud.
#
# With Colaboratory you can write and execute code, save and share your analyses, and access powerful computing resources, all for free from your browser.

# %%
#@title Introducing Colaboratory { display-mode: "form" }
#@markdown This 3-minute video gives an overview of the key features of Colaboratory:
from IPython.display import YouTubeVideo
YouTubeVideo('inN8seMm7UI', width=600, height=400)
# Out:
#         <iframe
#             width="600"
#             height="400"
#             src="https://www.youtube.com/embed/inN8seMm7UI"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Getting Started
#
# The document you are reading is a  [Jupyter notebook](https://jupyter.org/), hosted in Colaboratory. It is not a static page, but an interactive environment that lets you write and execute code in Python and other languages.
#
# For example, here is a **code cell** with a short Python script that computes a value, stores it in a variable, and prints the result:

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %% [markdown]
# To execute the code in the above cell, select it with a click and then either press the play button to the left of the code, or use the keyboard shortcut "Command/Ctrl+Enter".
#
# All cells modify the same global state, so variables that you define by executing a cell can be used in other cells:

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %% [markdown]
# For more information about working with Colaboratory notebooks, see [Overview of Colaboratory](/notebooks/basic_features_overview.ipynb).

# %% [markdown]
# ## More Resources
#
# Learn how to make the most of Python, Jupyter, Colaboratory, and related tools with these resources:
#
# ### Working with Notebooks in Colaboratory
# - [Overview of Colaboratory](/notebooks/basic_features_overview.ipynb)
# - [Guide to Markdown](/notebooks/markdown_guide.ipynb)
# - [Importing libraries and installing dependencies](/notebooks/snippets/importing_libraries.ipynb)
# - [Saving and loading notebooks in GitHub](https://colab.research.google.com/github/googlecolab/colabtools/blob/master/notebooks/colab-github-demo.ipynb)
# - [Interactive forms](/notebooks/forms.ipynb)
# - [Interactive widgets](/notebooks/widgets.ipynb)
#
# ### Working with Data
# - [Loading data: Drive, Sheets, and Google Cloud Storage](/notebooks/io.ipynb)
# - [Charts: visualizing data](/notebooks/charts.ipynb)
# - [Getting started with BigQuery](/notebooks/bigquery.ipynb)
#
# ### Machine Learning Crash Course
# These are a few of the notebooks from Google's online Machine Learning course. See the [full course website](https://developers.google.com/machine-learning/crash-course/) for more.
# - [Intro to Pandas](/notebooks/mlcc/intro_to_pandas.ipynb)
# - [Tensorflow concepts](/notebooks/mlcc/tensorflow_programming_concepts.ipynb)
# - [First steps with TensorFlow](/notebooks/mlcc/first_steps_with_tensor_flow.ipynb)
# - [Intro to neural nets](/notebooks/mlcc/intro_to_neural_nets.ipynb)
# - [Intro to sparse data and embeddings](/notebooks/mlcc/intro_to_sparse_data_and_embeddings.ipynb)
#
# ### Using Accelerated Hardware
# - [TensorFlow with GPUs](/notebooks/gpu.ipynb)
# - [TensorFlow with TPUs](/notebooks/tpu.ipynb)

# %% [markdown]
# ## Machine Learning Examples: Seedbank
#
# To see end-to-end examples of the interactive machine learning analyses that Colaboratory makes possible, check out the [Seedbank](https://research.google.com/seedbank/) project.
#
# A few featured examples:
#
# - [Neural Style Transfer](https://research.google.com/seedbank/seed/neural_style_transfer_with_tfkeras): Use deep learning to transfer style between images.
# - [EZ NSynth](https://research.google.com/seedbank/seed/ez_nsynth): Synthesize audio with WaveNet auto-encoders.
# - [Fashion MNIST with Keras and TPUs](https://research.google.com/seedbank/seed/fashion_mnist_with_keras_and_tpus): Classify fashion-related images with deep learning.
# - [DeepDream](https://research.google.com/seedbank/seed/deepdream): Produce DeepDream images from your own photos.
# - [Convolutional VAE](https://research.google.com/seedbank/seed/convolutional_vae): Create a generative model of handwritten digits.

# %%
# !pip install pyts
# Out:
# Collecting pyts
#   Downloading https://files.pythonhosted.org/packages/36/80/5f531de808dbf1625af0434f2fcc55f8c6488980d97ba2cab5cce285c527/pyts-0.9.0-py3-none-any.whl (2.5MB)
#      |████████████████████████████████| 2.5MB 2.8MB/s
# Requirement already satisfied: numpy>=1.15.4scipy>=1.3.0scikit-learn>=0.20.1numba>=0.41.0 in /usr/local/lib/python3.6/dist-packages (from pyts) (1.16.5)
# Installing collected packages: pyts
# Successfully installed pyts-0.9.0

# %%
# !pip install saxpy
# Out:
# Collecting saxpy
#   Downloading https://files.pythonhosted.org/packages/c1/06/c912c97c8348ffabf47b7c010f400574ef9fcf38ba33b449437e58b60c48/saxpy-1.0.1.dev167.tar.gz (178kB)
#      |████████████████████████████████| 184kB 2.8MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from saxpy) (1.16.5)
# Requirement already satisfied: pytest in /usr/local/lib/python3.6/dist-packages (from saxpy) (3.6.4)
# Collecting pytest-cov (from saxpy)
#   Downloading https://files.pythonhosted.org/packages/84/7b/73f8522619d1cbb22b9a36f9c54bc5ce5e24648e53cc1bf566477d2d1f2b/pytest_cov-2.7.1-py2.py3-none-any.whl
# Collecting codecov (from saxpy)
#   Downloading https://files.pythonhosted.org/packages/8b/28/4c1950a61c3c5786f0f34d643d0d28ec832433c9a7c0bd157690d4eb1d5f/codecov-2.0.15-py2.py3-none-any.whl
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.6/dist-packages (from pytest->saxpy) (19.1.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from pytest->saxpy) (1.12.0)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.6/dist-packages (from pytest->saxpy) (7.2.0)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from pytest->saxpy) (1.8.0)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.6/dist-packages (from pytest->saxpy) (1.3.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from pytest->saxpy) (41.2.0)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.6/dist-packages (from pytest->saxpy) (0.7.1)
# Collecting coverage>=4.4 (from pytest-cov->saxpy)
#   Downloading https://files.pythonhosted.org/packages/51/b1/13609068fff1c8c056f0c4601ad6985cf5c1bbfc529196ab08bd2a57dc39/coverage-4.5.4-cp36-cp36m-manylinux1_x86_64.whl (205kB)
#      |████████████████████████████████| 215kB 46.7MB/s
# Requirement already satisfied: requests>=2.7.9 in /usr/local/lib/python3.6/dist-packages (from codecov->saxpy) (2.21.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.7.9->codecov->saxpy) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.7.9->codecov->saxpy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.7.9->codecov->saxpy) (2019.6.16)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.7.9->codecov->saxpy) (1.24.3)
# Building wheels for collected packages: saxpy
#   Building wheel for saxpy (setup.py) ... done
#   Created wheel for saxpy: filename=saxpy-1.0.1.dev167-cp36-none-any.whl size=17669 sha256=f1178d4f150c15081526aee15f50ddaad1b5e69403f6497226a6b80d8f750371
#   Stored in directory: /root/.cache/pip/wheels/68/d1/a0/a2a4f96eb82607654bc45f00479af34ddd7c45be9096b8e63c
# Successfully built saxpy
# ERROR: datascience 0.10.6 has requirement coverage==3.7.1, but you'll have coverage 4.5.4 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: coveralls 0.5 has requirement coverage<3.999,>=3.6, but you'll have coverage 4.5.4 which is incompatible.
# Installing collected packages: coverage, pytest-cov, codecov, saxpy
#   Found existing installation: coverage 3.7.1
#     Uninstalling coverage-3.7.1:
#       Successfully uninstalled coverage-3.7.1
# Successfully installed codecov-2.0.15 coverage-4.5.4 pytest-cov-2.7.1 saxpy-1.0.1.dev167

# %%
import numpy as np
import random
import math
import operator
import matplotlib.pyplot as plt
from pyts.datasets import fetch_ucr_dataset
from pyts.metrics import dtw


def PAA(X_train,n):
    x = 0
    result = []

    for i in range(len(X_train)):
        if i % n == 0 and i != 0:
           result.append(x/n)
           x = 0
        x = x + X_train[i]
    return result

def euclideanDistance(instance1, instance2, length):
    distance = 0
    for x in range(length):
        distance += pow((instance1[x] - instance2[x]), 2)
    return math.sqrt(distance)


def Manha(instance1, instance2, length):
    distance = 0
    for x in range(length):
        distance += abs((instance1[x] - instance2[x]))
    return math.sqrt(distance)


def getNeighbors3(trainingSet, testInstance,k):
    distances = []
    length = len(testInstance) - 1
    for x in range(len(trainingSet)):
        dist = Manha(testInstance, trainingSet[x],length)
        distances.append((trainingSet[x], dist))
    distances.sort(key=operator.itemgetter(1))
    neighbors = []
    for x in range(k):
        neighbors.append(distances[x][0])
    return neighbors

def getNeighbors2(trainingSet, testInstance,k):
    distances = []
    for x in range(len(trainingSet)):
        dist = dtw(testInstance, trainingSet[x])
        distances.append((trainingSet[x], dist))
    distances.sort(key=operator.itemgetter(1))
    neighbors = []
    for x in range(k):
        neighbors.append(distances[x][0])
    return neighbors

def getNeighbors(trainingSet, testInstance, k):
    distances = []
    length = len(testInstance) - 1
    for x in range(len(trainingSet)):
        dist = euclideanDistance(testInstance, trainingSet[x], length)
        distances.append((trainingSet[x], dist))
    distances.sort(key=operator.itemgetter(1))
    neighbors = []
    for x in range(k):
        neighbors.append(distances[x][0])
    return neighbors


def getResponse(neighbors):
    classVotes = {}
    for x in range(len(neighbors)):
        response = neighbors[x][-1]
        if response in classVotes:
            classVotes[response] += 1
        else:
            classVotes[response] = 1
    sortedVotes = sorted(classVotes.items(), key=operator.itemgetter(1), reverse=True)
    return sortedVotes[0][0]


def getAccuracy(testSet, predictions):
    correct = 0
    for x in range(len(testSet)):
        if testSet[x][-1] == predictions[x]:
            correct += 1
    return (correct / float(len(testSet))) * 100.0


def main():

    X_train, X_test, y_train, y_test = fetch_ucr_dataset('InlineSkate', return_X_y=True)
    XTrain = [0]*len(X_train)
    XTest = [0]*len(X_test)

    for i in range(len(X_train)):
        XTrain[i] = PAA(X_train[i], 20)
    for i in range(len(X_test)):
        XTest[i] = PAA(X_test[i], 20)

    trainingSet = np.c_[XTrain, y_train]
    testSet = np.c_[XTest, y_test]

    predictions = []
    k = 1
    for x in range(len(testSet)):
        neighbors = getNeighbors3(trainingSet, testSet[x], k)
        result = getResponse(neighbors)
        predictions.append(result)
        print('> predicted=' + repr(result) + ', actual=' + repr(testSet[x][-1]))
    accuracy = getAccuracy(testSet, predictions)
    print('Accuracy: ' + repr(accuracy) + '%')


main()
# Out:
# > predicted=6.0, actual=6.0
# > predicted=6.0, actual=6.0
# > predicted=3.0, actual=4.0
# > predicted=4.0, actual=1.0
# > predicted=4.0, actual=4.0
# > predicted=3.0, actual=2.0
# > predicted=5.0, actual=6.0
# > predicted=7.0, actual=5.0
# > predicted=4.0, actual=4.0
# > predicted=3.0, actual=4.0
# > predicted=6.0, actual=4.0
# > predicted=5.0, actual=6.0
# > predicted=7.0, actual=7.0
# > predicted=3.0, actual=5.0
# > predicted=5.0, actual=2.0
# > predicted=5.0, actual=3.0
# > predicted=7.0, actual=7.0
# > predicted=2.0, actual=4.0
# > predicted=7.0, actual=3.0
# > predicted=2.0, actual=2.0
# > predicted=6.0, actual=2.0
# > predicted=3.0, actual=2.0
# > predicted=6.0, actual=6.0
# > predicted=2.0, actual=3.0
# > predicted=3.0, actual=2.0
# > predicted=2.0, actual=3.0
# > predicted=2.0, actual=2.0
# > predicted=2.0, actual=3.0
# > predicted=2.0, actual=1.0
# > predicted=3.0, actual=2.0
# > predicted=5.0, actual=4.0
# > predicted=6.0, actual=3.0
# > predicted=1.0, actual=1.0
# > predicted=5.0, actual=3.0
# > predicted=6.0, actual=5.0
# > predicted=2.0, actual=1.0
# > predicted=4.0, actual=1.0
# > predicted=4.0, actual=7.0
# > predicted=2.0, actual=1.0
# > predicted=5.0, actual=2.0
# > predicted=4.0, actual=4.0
# > predicted=5.0, actual=1.0
# > predicted=5.0, actual=6.0
# > predicted=4.0, actual=5.0
# > predicted=4.0, actual=4.0
# > predicted=7.0, actual=3.0
# > predicted=7.0, actual=7.0
# > predicted=5.0, actual=6.0
# > predicted=4.0, actual=4.0
# > predicted=3.0, actual=5.0
# > predicted=4.0, actual=4.0
# > predicted=4.0, actual=4.0
# > predicted=4.0, actual=3.0
# > predicted=4.0, actual=2.0
# > predicted=4.0, actual=6.0
# > predicted=5.0, actual=6.0
# > predicted=3.0, actual=5.0
# > predicted=7.0, actual=5.0
# > predicted=5.0, actual=6.0
# > predicted=4.0, actual=6.0
# > predicted=5.0, actual=4.0
# > predicted=3.0, actual=5.0
# > predicted=4.0, actual=4.0
# > predicted=5.0, actual=7.0
# > predicted=3.0, actual=3.0
# > predicted=6.0, actual=2.0
# > predicted=6.0, actual=6.0
# > predicted=6.0, actual=1.0
# > predicted=3.0, actual=2.0
# > predicted=3.0, actual=2.0
# > predicted=6.0, actual=5.0
# > predicted=5.0, actual=5.0
# > predicted=2.0, actual=7.0
# > predicted=4.0, actual=6.0
# > predicted=5.0, actual=6.0
# > predicted=4.0, actual=4.0
# > predicted=6.0, actual=5.0
# > predicted=4.0, actual=2.0
# > predicted=3.0, actual=5.0
# > predicted=5.0, actual=4.0
# > predicted=6.0, actual=5.0
# > predicted=3.0, actual=4.0
# > predicted=7.0, actual=7.0
# > predicted=2.0, actual=2.0
# > predicted=6.0, actual=6.0
# > predicted=6.0, actual=6.0
# > predicted=2.0, actual=4.0
# > predicted=5.0, actual=4.0
# > predicted=2.0, actual=2.0
# > predicted=6.0, actual=5.0
# > predicted=6.0, actual=6.0
# > predicted=4.0, actual=5.0
# > predicted=6.0, actual=5.0
# > predicted=6.0, actual=6.0
# > predicted=4.0, actual=4.0
# > predicted=6.0, actual=7.0
# > predicted=5.0, actual=6.0
# > predicted=6.0, actual=4.0
# > predicted=3.0, actual=3.0
# > predicted=7.0, actual=3.0
# > predicted=4.0, actual=2.0
# > predicted=4.0, actual=5.0
# > predicted=6.0, actual=1.0
# > predicted=3.0, actual=3.0
# > predicted=7.0, actual=4.0
# > predicted=7.0, actual=7.0
# > predicted=6.0, actual=6.0
# > predicted=1.0, actual=2.0
# > predicted=6.0, actual=5.0
# > predicted=6.0, actual=5.0
# > predicted=5.0, actual=5.0
# > predicted=4.0, actual=7.0
# > predicted=3.0, actual=4.0
# > predicted=4.0, actual=2.0
# > predicted=5.0, actual=5.0
# > predicted=4.0, actual=2.0
# > predicted=7.0, actual=7.0
# > predicted=5.0, actual=4.0
# > predicted=7.0, actual=6.0
# > predicted=7.0, actual=6.0
# > predicted=7.0, actual=5.0
# > predicted=2.0, actual=6.0
# > predicted=4.0, actual=4.0
# > predicted=7.0, actual=3.0
# > predicted=5.0, actual=5.0
# > predicted=6.0, actual=5.0
# > predicted=4.0, actual=4.0
# > predicted=7.0, actual=4.0
# > predicted=3.0, actual=3.0
# > predicted=3.0, actual=2.0
# > predicted=4.0, actual=3.0
# > predicted=3.0, actual=3.0
# > predicted=5.0, actual=3.0
# > predicted=3.0, actual=3.0
# > predicted=6.0, actual=4.0
# > predicted=3.0, actual=3.0
# > predicted=1.0, actual=7.0
# > predicted=3.0, actual=1.0
# > predicted=7.0, actual=4.0
# > predicted=7.0, actual=4.0
# > predicted=7.0, actual=6.0
# > predicted=6.0, actual=6.0
# > predicted=4.0, actual=5.0
# > predicted=7.0, actual=4.0
# > predicted=4.0, actual=4.0
# > predicted=7.0, actual=2.0
# > predicted=5.0, actual=5.0
# > predicted=2.0, actual=2.0
# > predicted=2.0, actual=2.0
# > predicted=3.0, actual=4.0
# > predicted=2.0, actual=2.0
# > predicted=5.0, actual=5.0
# > predicted=7.0, actual=3.0
# > predicted=2.0, actual=2.0
# > predicted=7.0, actual=4.0
# > predicted=2.0, actual=2.0
# > predicted=2.0, actual=3.0
# > predicted=1.0, actual=1.0
# > predicted=2.0, actual=3.0
# > predicted=3.0, actual=2.0
# > predicted=7.0, actual=7.0
# > predicted=7.0, actual=7.0
# > predicted=1.0, actual=1.0
# > predicted=3.0, actual=3.0
# > predicted=7.0, actual=4.0
# > predicted=5.0, actual=4.0
# > predicted=4.0, actual=7.0
# > predicted=7.0, actual=6.0
# > predicted=2.0, actual=1.0
# > predicted=5.0, actual=7.0
# > predicted=3.0, actual=3.0
# > predicted=2.0, actual=2.0
# > predicted=6.0, actual=6.0
# > predicted=4.0, actual=3.0
# > predicted=5.0, actual=5.0
# > predicted=5.0, actual=5.0
# > predicted=6.0, actual=6.0
# > predicted=4.0, actual=4.0
# > predicted=1.0, actual=1.0
# > predicted=4.0, actual=5.0
# > predicted=5.0, actual=3.0
# > predicted=6.0, actual=6.0
# > predicted=3.0, actual=1.0
# > predicted=7.0, actual=2.0
# > predicted=5.0, actual=5.0
# > predicted=4.0, actual=6.0
# > predicted=4.0, actual=4.0
# > predicted=3.0, actual=3.0
# > predicted=7.0, actual=5.0
# > predicted=2.0, actual=2.0
# > predicted=1.0, actual=1.0
# > predicted=5.0, actual=2.0
# > predicted=5.0, actual=7.0
# > predicted=7.0, actual=6.0
# > predicted=6.0, actual=2.0
# > predicted=6.0, actual=6.0
# > predicted=4.0, actual=2.0
# > predicted=4.0, actual=4.0
# > predicted=6.0, actual=5.0
# > predicted=2.0, actual=3.0
# > predicted=1.0, actual=2.0
# > predicted=5.0, actual=5.0
# > predicted=1.0, actual=1.0
# > predicted=3.0, actual=3.0
# > predicted=4.0, actual=6.0
# > predicted=2.0, actual=2.0
# > predicted=2.0, actual=2.0
# > predicted=3.0, actual=5.0
# > predicted=6.0, actual=5.0
# > predicted=2.0, actual=1.0
# > predicted=3.0, actual=2.0
# > predicted=7.0, actual=5.0
# > predicted=6.0, actual=2.0
# > predicted=4.0, actual=4.0
# > predicted=3.0, actual=4.0
# > predicted=7.0, actual=7.0
# > predicted=5.0, actual=3.0
# > predicted=3.0, actual=4.0
# > predicted=3.0, actual=2.0
# > predicted=2.0, actual=4.0
# > predicted=5.0, actual=7.0
# > predicted=6.0, actual=5.0
# > predicted=3.0, actual=5.0
# > predicted=5.0, actual=7.0
# > predicted=6.0, actual=4.0
# > predicted=7.0, actual=7.0
# > predicted=1.0, actual=1.0
# > predicted=5.0, actual=7.0
# > predicted=1.0, actual=3.0
# > predicted=6.0, actual=6.0
# > predicted=3.0, actual=3.0
# > predicted=3.0, actual=1.0
# > predicted=3.0, actual=3.0
# > predicted=5.0, actual=6.0
# > predicted=2.0, actual=3.0
# > predicted=6.0, actual=1.0
# > predicted=3.0, actual=2.0
# > predicted=4.0, actual=4.0
# > predicted=2.0, actual=5.0
# > predicted=5.0, actual=5.0
# > predicted=2.0, actual=2.0
# > predicted=5.0, actual=6.0
# > predicted=5.0, actual=5.0
# > predicted=4.0, actual=4.0
# > predicted=3.0, actual=5.0
# > predicted=7.0, actual=6.0
# > predicted=6.0, actual=4.0
# > predicted=6.0, actual=2.0
# > predicted=7.0, actual=7.0
# > predicted=6.0, actual=5.0
# > predicted=6.0, actual=1.0
# > predicted=5.0, actual=5.0
# > predicted=3.0, actual=3.0
# > predicted=7.0, actual=7.0
# > predicted=3.0, actual=3.0
# > predicted=3.0, actual=4.0
# > predicted=4.0, actual=3.0
# > predicted=7.0, actual=5.0
# > predicted=4.0, actual=5.0
# > predicted=4.0, actual=2.0
# > predicted=3.0, actual=5.0
# > predicted=6.0, actual=6.0
# > predicted=7.0, actual=3.0
# > predicted=4.0, actual=5.0
# > predicted=7.0, actual=6.0
# > predicted=4.0, actual=4.0
# > predicted=4.0, actual=1.0
# > predicted=5.0, actual=7.0
# > predicted=1.0, actual=1.0
# > predicted=4.0, actual=4.0
# > predicted=3.0, actual=5.0
# > predicted=6.0, actual=6.0
# > predicted=4.0, actual=4.0
# > predicted=4.0, actual=5.0
# > predicted=6.0, actual=4.0
# > predicted=3.0, actual=3.0
# > predicted=5.0, actual=1.0
# > predicted=5.0, actual=2.0
# > predicted=4.0, actual=2.0
# > predicted=6.0, actual=6.0
# > predicted=5.0, actual=4.0
# > predicted=7.0, actual=6.0
# > predicted=5.0, actual=6.0
# > predicted=2.0, actual=2.0
# > predicted=4.0, actual=2.0
# > predicted=5.0, actual=6.0
# > predicted=6.0, actual=1.0
# > predicted=5.0, actual=3.0
# > predicted=6.0, actual=4.0
# > predicted=6.0, actual=4.0
# > predicted=2.0, actual=3.0
# > predicted=5.0, actual=4.0
# > predicted=4.0, actual=4.0
# > predicted=6.0, actual=1.0
# > predicted=7.0, actual=7.0
# > predicted=4.0, actual=4.0
# > predicted=5.0, actual=3.0
# > predicted=3.0, actual=4.0
# > predicted=5.0, actual=5.0
# > predicted=2.0, actual=6.0
# > predicted=3.0, actual=6.0
# > predicted=6.0, actual=3.0
# > predicted=3.0, actual=2.0
# > predicted=4.0, actual=4.0
# > predicted=6.0, actual=4.0
# > predicted=3.0, actual=3.0
# > predicted=7.0, actual=3.0
# > predicted=4.0, actual=4.0
# > predicted=7.0, actual=3.0
# > predicted=7.0, actual=6.0
# > predicted=7.0, actual=6.0
# > predicted=5.0, actual=7.0
# > predicted=3.0, actual=5.0
# > predicted=3.0, actual=4.0
# > predicted=4.0, actual=4.0
# > predicted=2.0, actual=1.0
# > predicted=6.0, actual=6.0
# > predicted=7.0, actual=3.0
# > predicted=6.0, actual=5.0
# > predicted=4.0, actual=7.0
# > predicted=6.0, actual=2.0
# > predicted=4.0, actual=1.0
# > predicted=7.0, actual=4.0
# > predicted=7.0, actual=4.0
# > predicted=4.0, actual=2.0
# > predicted=5.0, actual=5.0
# > predicted=5.0, actual=6.0
# > predicted=7.0, actual=5.0
# > predicted=5.0, actual=5.0
# > predicted=5.0, actual=2.0
# > predicted=4.0, actual=6.0
# > predicted=5.0, actual=1.0
# > predicted=6.0, actual=5.0
# > predicted=7.0, actual=5.0
# > predicted=4.0, actual=7.0
# > predicted=3.0, actual=4.0
# > predicted=5.0, actual=5.0
# > predicted=3.0, actual=5.0
# > predicted=5.0, actual=7.0
# > predicted=3.0, actual=3.0
# > predicted=4.0, actual=4.0
# > predicted=5.0, actual=2.0
# > predicted=5.0, actual=5.0
# > predicted=3.0, actual=5.0
# > predicted=3.0, actual=6.0
# > predicted=6.0, actual=6.0
# > predicted=7.0, actual=7.0
# > predicted=2.0, actual=2.0
# > predicted=6.0, actual=3.0
# > predicted=4.0, actual=4.0
# > predicted=4.0, actual=4.0
# > predicted=7.0, actual=4.0
# > predicted=3.0, actual=3.0
# > predicted=7.0, actual=6.0
# > predicted=4.0, actual=7.0
# > predicted=6.0, actual=5.0
# > predicted=7.0, actual=2.0
# > predicted=4.0, actual=5.0
# > predicted=2.0, actual=4.0
# > predicted=7.0, actual=4.0
# > predicted=4.0, actual=5.0
# > predicted=7.0, actual=5.0
# > predicted=6.0, actual=6.0
# > predicted=3.0, actual=3.0
# > predicted=2.0, actual=2.0
# > predicted=4.0, actual=5.0
# > predicted=7.0, actual=7.0
# > predicted=7.0, actual=5.0
# > predicted=3.0, actual=1.0
# > predicted=4.0, actual=6.0
# > predicted=2.0, actual=4.0
# > predicted=4.0, actual=1.0
# > predicted=5.0, actual=3.0
# > predicted=6.0, actual=5.0
# > predicted=7.0, actual=4.0
# > predicted=6.0, actual=5.0
# > predicted=6.0, actual=6.0
# > predicted=1.0, actual=1.0
# > predicted=5.0, actual=5.0
# > predicted=6.0, actual=5.0
# > predicted=5.0, actual=4.0
# > predicted=5.0, actual=3.0
# > predicted=6.0, actual=5.0
# > predicted=4.0, actual=5.0
# > predicted=7.0, actual=3.0
# > predicted=7.0, actual=7.0
# > predicted=6.0, actual=3.0
# > predicted=5.0, actual=5.0
# > predicted=3.0, actual=7.0
# > predicted=4.0, actual=6.0
# > predicted=4.0, actual=1.0
# > predicted=7.0, actual=6.0
# > predicted=5.0, actual=3.0
# > predicted=3.0, actual=3.0
# > predicted=6.0, actual=6.0
# > predicted=5.0, actual=5.0
# > predicted=7.0, actual=3.0
# > predicted=1.0, actual=1.0
# > predicted=7.0, actual=7.0
# > predicted=4.0, actual=2.0
# > predicted=3.0, actual=1.0
# > predicted=2.0, actual=1.0
# > predicted=2.0, actual=1.0
# > predicted=1.0, actual=1.0
# > predicted=5.0, actual=5.0
# > predicted=2.0, actual=2.0
# > predicted=3.0, actual=3.0
# > predicted=3.0, actual=3.0
# > predicted=7.0, actual=7.0
# > predicted=7.0, actual=5.0
# > predicted=6.0, actual=6.0
# > predicted=2.0, actual=2.0
# > predicted=4.0, actual=6.0
# > predicted=4.0, actual=2.0
# > predicted=7.0, actual=7.0
# > predicted=3.0, actual=5.0
# > predicted=1.0, actual=1.0
# > predicted=7.0, actual=3.0
# > predicted=4.0, actual=2.0
# > predicted=2.0, actual=6.0
# > predicted=6.0, actual=6.0
# > predicted=4.0, actual=6.0
# > predicted=4.0, actual=5.0
# > predicted=7.0, actual=5.0
# > predicted=3.0, actual=3.0
# > predicted=1.0, actual=1.0
# > predicted=2.0, actual=2.0
# > predicted=5.0, actual=7.0
# > predicted=7.0, actual=2.0
# > predicted=1.0, actual=1.0
# > predicted=5.0, actual=5.0
# > predicted=6.0, actual=5.0
# > predicted=5.0, actual=7.0
# > predicted=3.0, actual=5.0
# > predicted=1.0, actual=1.0
# > predicted=6.0, actual=5.0
# > predicted=3.0, actual=5.0
# > predicted=6.0, actual=5.0
# > predicted=3.0, actual=3.0
# > predicted=2.0, actual=7.0
# > predicted=6.0, actual=6.0
# > predicted=4.0, actual=2.0
# > predicted=1.0, actual=3.0
# > predicted=5.0, actual=5.0
# > predicted=2.0, actual=3.0
# > predicted=2.0, actual=4.0
# > predicted=4.0, actual=3.0
# > predicted=6.0, actual=5.0
# > predicted=3.0, actual=3.0
# > predicted=6.0, actual=3.0
# > predicted=4.0, actual=6.0
# > predicted=5.0, actual=3.0
# > predicted=6.0, actual=3.0
# > predicted=3.0, actual=2.0
# > predicted=1.0, actual=2.0
# > predicted=3.0, actual=2.0
# > predicted=6.0, actual=6.0
# > predicted=4.0, actual=4.0
# > predicted=4.0, actual=4.0
# > predicted=6.0, actual=2.0
# > predicted=7.0, actual=7.0
# > predicted=5.0, actual=4.0
# > predicted=4.0, actual=2.0
# > predicted=4.0, actual=5.0
# > predicted=4.0, actual=5.0
# > predicted=3.0, actual=5.0
# > predicted=5.0, actual=3.0
# > predicted=4.0, actual=4.0
# > predicted=7.0, actual=6.0
# > predicted=3.0, actual=3.0
# > predicted=3.0, actual=3.0
# > predicted=4.0, actual=7.0
# > predicted=7.0, actual=7.0
# > predicted=1.0, actual=6.0
# > predicted=3.0, actual=2.0
# > predicted=5.0, actual=6.0
# > predicted=6.0, actual=6.0
# > predicted=4.0, actual=6.0
# > predicted=1.0, actual=1.0
# > predicted=5.0, actual=4.0
# > predicted=3.0, actual=5.0
# > predicted=4.0, actual=7.0
# > predicted=4.0, actual=2.0
# > predicted=2.0, actual=1.0
# > predicted=6.0, actual=5.0
# > predicted=1.0, actual=2.0
# > predicted=6.0, actual=6.0
# > predicted=4.0, actual=2.0
# > predicted=5.0, actual=3.0
# > predicted=7.0, actual=7.0
# > predicted=5.0, actual=4.0
# > predicted=2.0, actual=2.0
# > predicted=4.0, actual=6.0
# > predicted=5.0, actual=3.0
# > predicted=1.0, actual=1.0
# > predicted=5.0, actual=6.0
# > predicted=3.0, actual=2.0
# > predicted=4.0, actual=2.0
# > predicted=7.0, actual=6.0
# > predicted=4.0, actual=2.0
# > predicted=1.0, actual=1.0
# > predicted=6.0, actual=3.0
# > predicted=1.0, actual=1.0
# > predicted=6.0, actual=6.0
# > predicted=6.0, actual=4.0
# > predicted=6.0, actual=3.0
# > predicted=2.0, actual=2.0
# > predicted=4.0, actual=1.0
# > predicted=5.0, actual=4.0
# > predicted=6.0, actual=3.0
# > predicted=3.0, actual=3.0
# > predicted=5.0, actual=7.0
# > predicted=2.0, actual=2.0
# > predicted=2.0, actual=2.0
# > predicted=5.0, actual=5.0
# > predicted=5.0, actual=3.0
# > predicted=1.0, actual=6.0
# > predicted=7.0, actual=7.0
# > predicted=5.0, actual=4.0
# > predicted=3.0, actual=1.0
# > predicted=5.0, actual=1.0
# > predicted=4.0, actual=4.0
# > predicted=3.0, actual=3.0
# > predicted=3.0, actual=3.0
# > predicted=3.0, actual=6.0
# > predicted=3.0, actual=2.0
# > predicted=5.0, actual=4.0
# > predicted=2.0, actual=3.0
# > predicted=7.0, actual=7.0
# > predicted=6.0, actual=5.0
# > predicted=5.0, actual=6.0
# > predicted=4.0, actual=7.0
# > predicted=4.0, actual=2.0
# > predicted=3.0, actual=3.0
# > predicted=4.0, actual=2.0
# > predicted=2.0, actual=1.0
# > predicted=4.0, actual=4.0
# > predicted=6.0, actual=6.0
# > predicted=4.0, actual=5.0
# > predicted=7.0, actual=5.0
# > predicted=6.0, actual=2.0
# > predicted=5.0, actual=5.0
# > predicted=3.0, actual=6.0
# > predicted=5.0, actual=7.0
# > predicted=4.0, actual=1.0
# > predicted=2.0, actual=2.0
# > predicted=3.0, actual=2.0
# > predicted=4.0, actual=6.0
# > predicted=5.0, actual=5.0
# > predicted=7.0, actual=4.0
# Accuracy: 35.090909090909086%
