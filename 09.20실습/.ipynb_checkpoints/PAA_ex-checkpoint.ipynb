# %%
import csv
import random
import operator
from math import *
import numpy as np
import sys
from pyts.datasets import load_gunpoint
import math


def PAAn3(n):
    X_train, X_test, y_train, y_test = load_gunpoint(return_X_y=True)
    tempe = 0.0
    list = []
    print(len(X_train[1]))
    for i in range(n-1,len(X_train[1])):
        if i%n == n-1:
            tempe = 0
            for p in range(i-n+1,i+1):
                tempe += X_train[1][p] 
            list.append(tempe/n)
        
    print(list)
    print(len(list))

PAAn3(5)
PAAn3(3)
PAAn3(2)
# Out:
# 150
# [-0.64625686, -0.638478044, -0.6323452279999999, -0.62324319, -0.6095063639999999, -0.610849524, -0.608224436, -0.5991798180000001, -0.5958110440000001, -0.547265376, -0.18282763400000002, 0.654022754, 1.41154866, 1.85669978, 1.9095089600000001, 1.9200999600000004, 1.9157856199999999, 1.7321967600000001, 1.1166721919999998, 0.40569226379999995, -0.487456128, -0.801309526, -0.7654534399999999, -0.7022612739999999, -0.6641352140000001, -0.64655432, -0.644588086, -0.6426639599999999, -0.639462092, -0.634355414]
# 30
# 150
# ...
